# %%
import pandas as pd
import bar_chart_race_custom as bcr

# %%
# Color picker online

club_colors = {
    # Ligue 1 / Ligue 2 historiques
    "Paris Saint-Germain": "#004170",     # bleu PSG
    "Olympique Marseille": "#00d0cd",     # bleu ciel OM
    "Olympique Lyonnais": "#0007d0",      # rouge OL
    "AS Saint-Étienne": "#00845d",        # vert ASSE
    "AS Monaco": "#d00018",               # rouge Monaco
    "RC Lens": "#f7d117",                 # jaune Lens
    "RC Strasbourg": "#005BAC",           # bleu Strasbourg
    "Lille OSC": "#e41b17",                    # rouge Lille
    "FC Nantes": "#ffe100",               # jaune canari
    "Stade Rennais": "#d2001c",           # rouge Rennes
    "Stade de Reims": "#e30613",          # rouge Reims
    "Stade Brestois 29": "#e30613",       # rouge Brest
    "Montpellier HSC": "#ff6600",         # orange MHSC
    "OGC Nice": "#e30613",                # rouge Nice
    "Toulouse FC": "#52328b",             # violet TFC
    "Girondins Bordeaux": "#00295b",      # bleu marine
    "FC Metz": "#7a1529",                 # grenat
    "FC Lorient": "#ff7f00",              # orange Lorient
    "Angers SCO": "#000000",              # noir Angers
    "Dijon FCO": "#d2001c",               # rouge Dijon
    "Nîmes Olympique": "#e30613",         # rouge Nîmes
    "SM Caen": "#002147",                 # bleu marine
    "Clermont Foot 63": "#143c8c",        # bleu Clermont
    "AC Ajaccio": "#e30613",              # rouge Ajaccio
    "Gazélec FC Ajaccio": "#003da5",      # bleu GFC Ajaccio
    "SC Bastia": "#004a99",               # bleu Bastia
    "Valenciennes FC": "#e30613",         # rouge VAFC
    "Havre AC": "#1a496d",                # bleu ciel Havre
    "EA Guingamp": "#e30613",             # rouge Guingamp
    "AJ Auxerre": "#005bac",              # bleu Auxerre
    "CS Sedan": "#006633",                # vert Sedan
    "LB Châteauroux": "#002395",          # bleu Châteauroux
    "Le Mans FC": "#d71a28",              # rouge Le Mans
    "Stade Lavallois": "#ff6600",         # orange Laval
    "Red Star FC": "#006633",             # vert Red Star
    "FC Sochaux": "#ffd700",                 # jaune Sochaux
    "Grenoble Foot 38": "#0046ad",        # bleu Grenoble
    "Rodez AF": "#ff0000",                # rouge Rodez
    "Amiens SC": "#c0c0c0",               # gris Amiens
    "US Orléans": "#ffcc00",              # jaune Orléans
    "USL Dunkerque": "#005bac",           # bleu Dunkerque
    "US Concarneau": "#0072bb",           # bleu Concarneau
    "US Boulogne": "#d71a28",             # rouge/noir
    "Quevilly-Rouen": "#ffcc00",          # jaune
    "Tours FC": "#1f75fe",                # bleu clair Tours
    "Évian Thonon Gaillard": "#ff7f7f",   # rose ETG
    "Vannes OC": "#000000",               # noir Vannes
    "US Créteil-Lusitanos": "#00a859",    # vert Créteil
    "Chamois Niortais": "#005bac",        # bleu Niort

    # Clubs nationaux / historiques
    "FC Rouen 1899": "#d71a28",           # rouge Rouen
    "FC Sète": "#008000",                 # vert
    "FC Versailles": "#002395",           # bleu roi
    "FC Villefranche Beaujolais": "#0047ab", # bleu
    "FC Gueugnon": "#ffd700",             # jaune
    "FC Martigues": "#ffcc00",            # jaune/rouge
    "FC Mulhouse": "#0047ab",             # bleu
    "US Avranches": "#005bac",            # bleu
    "Stade Briochin": "#ffcc00",          # jaune
    "Stade Poitevin": "#000000",          # noir
    "Stade Plabennec": "#ff0000",         # rouge
    "Stade Beaucairois": "#000000",       # noir
    "Saint-Denis Saint-Leu FC": "#008000", # vert
    "Calais RUFC": "#ff0000",             # rouge
    "FC Chambly": "#000000",              # noir/jaune
    "Pau FC": "#ffcc00",                  # jaune
    "FC Annecy": "#d71a28",               # rouge
    "US Colomiers": "#0000ff",            # bleu
    "US Lusitanos de Saint-Maur": "#006400", # vert
    "AS Cannes": "#ff0000",               # rouge
    "Racing Besançon": "#d71a28",         # rouge
    "RC France 92": "#002395",            # bleu roi
    "Paris FC": "#002395",                # bleu foncé
    "Paris 13 Atletico": "#0099cc",       # bleu clair
    "Marseille Consolat": "#008000",      # vert
    "Marignane Gignac": "#ffcc00",        # jaune
    "GOAL FC": "#000000",                 # noir
    "Louhans-Cuiseaux": "#ffff00",        # jaune
    "Vendée Les Herbiers": "#e30613",     # rouge
    "Trélissac FC": "#0047ab",            # bleu
    "SAS Épinal": "#ffd700",              # jaune
    "SR Colmar": "#006400",               # vert
    "AS Nancy Lorraine": "#e30613",       # rouge
    "Stade Rennais": "#e30613",           # rouge (doublon) 
    "ESTAC Troyes": "#005bac",          # bleu
}

# %%
df = pd.read_csv("C:\\1_Programmes Python\\Statistiques\\Classement Elo foot\\New version\\Elo\\ratings_timeseries.csv", index_col=0)  # index = dates, colonnes = toutes les équipes
df = df.astype(float)
df.index = pd.to_datetime(df.index)

# %% [markdown]
# Compter 9 frames par seconde de run.

# %%
def race(k, duration, spp,bars,title,file_to_save): # k = step, duration en ms, spp = steps per period
    df_ = df.iloc[::k]

    n = len(df_)

    total_frames = n * spp # steps_per_period

    period_duration = duration/n

    fps = 1000*spp/period_duration # frames per second

    run_duration_min = int(total_frames/(9*60))

    run_duration_sec = int((total_frames/(9*60) - run_duration_min)*60)

    print("duration : ", total_frames/fps) # durée de la vidéo en secondes
    print("total_frames : ", total_frames)
    print("fps : ", fps)
    print("échantillons : ", n)
    print("period_duration : ", period_duration)
    print("durée du run environ : ", run_duration_min, "min", run_duration_sec, "s")

    file = "C:\\1_Programmes Python\\Statistiques\\Classement Elo foot\\New version\\Bart Chart Race Elo\\" + file_to_save + ".mp4"

    colors = [club_colors.get(col, '#aaaaaa') for col in df.columns]

    bcr.bar_chart_race(
        df=df_,
        filename=file,
        orientation='h',
        sort='desc',
        writer="ffmpeg",
        dpi = 144,
        n_bars=bars,
        fixed_order=False,
        steps_per_period=spp, # si interpolate est à False, ça ne sert à rien
        period_fmt = '%Y-%m-%d', # résout le pb d'affichage des dates !
        interpolate_period=True, 
        period_length=period_duration, # en ms
        figsize=(12,6),
        title=title,
        bar_kwargs={'alpha': .7},   # pas de 'color' ici !
        cmap=colors,                 # <-- liste de couleurs par colonne
        filter_column_colors=False,
        title_size=16,
        tick_label_size=10, 
        logos_path="C:\\1_Programmes Python\\Statistiques\\Classement Elo foot\\New version\\Logos\\Logos_resized\\", # chemin vers le dossier des logos

    )

# %%
k = 60 # 1 frame toutes les k lignes, en général une équipe change d'Elo tous les 30 lignes. 

duration = 4*60000 # durée de la vidéo en ms

spp = 40 # steps per period, 40 permet d'avoir une transition fluide, et des dépassements corrects

bars = 10 # top 6 et plus, affichage correct des logos, en dessous pb

title = "CLASSEMENT ELO TOP " + str(bars) + " CLUBS FRANCAIS" 

file_to_save = "Elo_" + "k" + str(k) + "_duration" + str(int(duration/1000)) + "s" + "_spp" + str(spp) + "_top" + str(bars)

print(file_to_save)
# Out:
# Elo_k60_duration240s_spp40_top10

# %% [markdown]
# k = 60, spp = 40, bars = 10, duration = 240 000 : 21min de run pour 1min42s de vidéo sur 4min

# %%
race(k, duration, spp,bars,title,file_to_save)
# Out:
# duration :  240.0
# total_frames :  20520
# fps :  85.5
# échantillons :  513
# period_duration :  467.8362573099415
# durée du run environ :  38 min 0 s
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 127 () missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 128 (\x80) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 129 (\x81) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 130 (\x82) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 131 (\x83) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 132 (\x84) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 133 (\x85) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 134 (\x86) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 135 (\x87) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 136 (\x88) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 137 (\x89) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 138 (\x8a) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 139 (\x8b) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 140 (\x8c) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 141 (\x8d) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 142 (\x8e) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 143 (\x8f) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 144 (\x90) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 145 (\x91) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 146 (\x92) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 147 (\x93) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 148 (\x94) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 149 (\x95) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 150 (\x96) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 151 (\x97) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 152 (\x98) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 153 (\x99) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 154 (\x9a) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 155 (\x9b) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 156 (\x9c) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 157 (\x9d) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 158 (\x9e) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:301: UserWarning: Glyph 159 (\x9f) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:303: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(self.df_values.columns)
# c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:304: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 race(k, duration, spp,bars,title,file_to_save)
#
# Cell In[28], line 27, in race(k, duration, spp, bars, title, file_to_save)
#      23 file = "C:\\1_Programmes Python\\Statistiques\\Classement Elo foot\\New version\\Bart Chart Race Elo\\" + file_to_save + ".mp4"
#      25 colors = [club_colors.get(col, '#aaaaaa') for col in df.columns]
# ---> 27 bcr.bar_chart_race(
#      28     df=df_,
#      29     filename=file,
#      30     orientation='h',
#      31     sort='desc',
#      32     writer="ffmpeg",
#      33     dpi = 144,
#      34     n_bars=bars,
#      35     fixed_order=False,
#      36     steps_per_period=spp, # si interpolate est à False, ça ne sert à rien
#      37     period_fmt = '%Y-%m-%d', # résout le pb d'affichage des dates !
#      38     interpolate_period=True,
#      39     period_length=period_duration, # en ms
#      40     figsize=(12,6),
#      41     title=title,
#      42     bar_kwargs={'alpha': .7},   # pas de 'color' ici !
#      43     cmap=colors,                 # <-- liste de couleurs par colonne
#      44     filter_column_colors=False,
#      45     title_size=16,
#      46     tick_label_size=10,
#      47     logos_path="C:\\1_Programmes Python\\Statistiques\\Classement Elo foot\\New version\\Logos\\Logos_resized\\", # chemin vers le dossier des logos
#      48
#      49 )
#
# File c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:845, in bar_chart_race(df, filename, orientation, sort, n_bars, fixed_order, fixed_max, steps_per_period, period_length, interpolate_period, label_bars, bar_size, period_label, period_fmt, period_summary_func, perpendicular_bar_func, figsize, cmap, title, title_size, bar_label_size, tick_label_size, shared_fontdict, scale, writer, fig, dpi, bar_kwargs, filter_column_colors, logos_path)
#     523 '''
#     524 Create an animated bar chart race using matplotlib. Data must be in
#     525 'wide' format where each row represents a single time period and each
#    (...)    838 These sizes are relative to plt.rcParams['font.size'].
#     839 '''
#     840 bcr = _BarChartRace(df, filename, orientation, sort, n_bars, fixed_order, fixed_max,
#     841                     steps_per_period, period_length, interpolate_period, label_bars, bar_size,
#     842                     period_label, period_fmt, period_summary_func, perpendicular_bar_func,
#     843                     figsize, cmap, title, title_size, bar_label_size, tick_label_size,
#     844                     shared_fontdict, scale, writer, fig, dpi, bar_kwargs, filter_column_colors,logos_path)
# --> 845 return bcr.make_animation()
#
# File c:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Programmes\bar_chart_race_custom\_make_chart.py:497, in _BarChartRace.make_animation(self)
#     495             pass
#     496     else:
# --> 497         ret_val = anim.save(self.filename, fps=self.fps, writer=self.writer)
#     498 except Exception as e:
#     499     if self.extension != 'gif':
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\animation.py:1126, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1124         progress_callback(frame_number, total_frames)
#    1125         frame_number += 1
# -> 1126 writer.grab_frame(**savefig_kwargs)
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\animation.py:352, in MovieWriter.grab_frame(self, **savefig_kwargs)
#     350 self.fig.set_size_inches(self._w, self._h)
#     351 # Save the figure data to the sink, using the frame format and dpi.
# --> 352 self.fig.savefig(self._proc.stdin, format=self.frame_format,
#     353                  dpi=self.dpi, **savefig_kwargs)
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:417, in FigureCanvasAgg.print_raw(self, filename_or_obj, metadata)
#     415 if metadata is not None:
#     416     raise ValueError("metadata not supported for raw/rgba")
# --> 417 FigureCanvasAgg.draw(self)
#     418 renderer = self.get_renderer()
#     419 with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axes\_base.py:3190, in _AxesBase.draw(self, renderer)
#    3187     for spine in self.spines.values():
#    3188         artists.remove(spine)
# -> 3190 self._update_title_position(renderer)
#    3192 if not self.axison:
#    3193     for _axis in self._axis_map.values():
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axes\_base.py:3134, in _AxesBase._update_title_position(self, renderer)
#    3132 if title.get_text():
#    3133     for ax in axs:
# -> 3134         ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3135         if ax.yaxis.offsetText.get_text():
#    3136             bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axis.py:1353, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1350     renderer = self.get_figure(root=True)._get_renderer()
#    1351 ticks_to_draw = self._update_ticks()
# -> 1353 self._update_label_position(renderer)
#    1355 # go back to just this axis's tick labels
#    1356 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axis.py:2675, in YAxis._update_label_position(self, renderer)
#    2671     return
#    2673 # get bounding boxes for this axis and any siblings
#    2674 # that have been set by `fig.align_ylabels()`
# -> 2675 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2676 x, y = self.label.get_position()
#    2678 if self.label_position == 'left':
#    2679     # Union with extents of the left spine if present, of the axes otherwise.
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axis.py:2241, in Axis._get_tick_boxes_siblings(self, renderer)
#    2239 axis = ax._axis_map[name]
#    2240 ticks_to_draw = axis._update_ticks()
# -> 2241 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2242 bboxes.extend(tlb)
#    2243 bboxes2.extend(tlb2)
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axis.py:1332, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1330 if renderer is None:
#    1331     renderer = self.get_figure(root=True)._get_renderer()
# -> 1332 return ([tick.label1.get_window_extent(renderer)
#    1333          for tick in ticks if tick.label1.get_visible()],
#    1334         [tick.label2.get_window_extent(renderer)
#    1335          for tick in ticks if tick.label2.get_visible()])
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\text.py:969, in Text.get_window_extent(self, renderer, dpi)
#     964     raise RuntimeError(
#     965         "Cannot get window extent of text w/o renderer. You likely "
#     966         "want to call 'figure.draw_without_rendering()' first.")
#     968 with cbook._setattr_cm(fig, dpi=dpi):
# --> 969     bbox, info, descent = self._get_layout(self._renderer)
#     970     x, y = self.get_unitless_position()
#     971     x, y = self.get_transform().transform((x, y))
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\text.py:382, in Text._get_layout(self, renderer)
#     380 clean_line, ismath = self._preprocess_math(line)
#     381 if clean_line:
# --> 382     w, h, d = _get_text_metrics_with_cache(
#     383         renderer, clean_line, self._fontproperties,
#     384         ismath=ismath, dpi=self.get_figure(root=True).dpi)
#     385 else:
#     386     w = h = d = 0
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:219, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     216     return width, height, descent
#     218 font = self._prepare_font(prop)
# --> 219 font.set_text(s, 0.0, flags=get_hinting_flag())
#     220 w, h = font.get_width_height()  # width and height of unrotated string
#     221 d = font.get_descent()
#
# KeyboardInterrupt:
