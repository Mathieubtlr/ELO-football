# %% [markdown]
# ## Checking sizes

# %%
import os
from PIL import Image

def check_logo_sizes(folder):
    """
    Affiche la taille (largeur, hauteur) de chaque logo dans un dossier.
    
    Args:
        folder (str): chemin du dossier contenant les logos
    """
    for file in os.listdir(folder):
        if file.lower().endswith((".png", ".jpg", ".jpeg")):
            path = os.path.join(folder, file)
            try:
                with Image.open(path) as img:
                    print(f"{file:30} -> {img.size}")  # (largeur, hauteur)
            except Exception as e:
                print(f"⚠️ Erreur avec {file}: {e}")

# Exemple d'utilisation
check_logo_sizes("C:\\1_Programmes Python\\Statistiques\\Classement Elo foot\\New version\\Logos\\logos_original_size")
# Out:
# AC Ajaccio.png                 -> (225, 299)
# AC Arles-Avignon.png           -> (330, 330)
# AJ Auxerre.png                 -> (310, 392)
# Amiens SC.png                  -> (270, 324)
# Angers SCO.png                 -> (255, 305)
# AS Angoulême Charente.png      -> (330, 330)
# AS Beauvais.png                -> (300, 304)
# AS Béziers.png                 -> (270, 323)
# AS Cannes.png                  -> (300, 355)
# AS Cherbourg.png               -> (300, 300)
# AS Lyon Duchère.png            -> (330, 341)
# AS Monaco.png                  -> (203, 352)
# AS Moulins.png                 -> (300, 250)
# AS Nancy Lorraine.png          -> (270, 316)
# AS Saint-Priest.png            -> (270, 359)
# AS Saint-Étienne.png           -> (330, 412)
# AS Yzeure FC.png               -> (375, 472)
# AS Évry.png                    -> (375, 453)
# ASM Belfort.png                -> (200, 137)
# ASOA Valence.png               -> (330, 498)
# Aviron Bayonnais.png           -> (270, 313)
# CA Bastia.png                  -> (375, 437)
# Calais RUFC.png                -> (300, 307)
# Chamois Niortais.png           -> (240, 297)
# Clermont Foot 63.png           -> (270, 336)
# CS Sedan.png                   -> (320, 407)
# Dijon FCO.png                  -> (300, 328)
# EA Guingamp.png                -> (330, 330)
# Entente SSG.png                -> (300, 384)
# ES Uzès Pont du Gard.png       -> (733, 900)
# ES Viry-Châtillon.png          -> (169, 159)
# ES Wasquehal.png               -> (375, 375)
# ESTAC Troyes.png               -> (330, 403)
# FC Annecy.png                  -> (285, 330)
# FC Borgo.png                   -> (285, 323)
# FC Bourg-Péronnas.png          -> (270, 334)
# FC Chambly.png                 -> (270, 270)
# FC Fleury 91.png               -> (330, 362)
# FC Gueugnon.png                -> (375, 375)
# FC Istres.png                  -> (270, 352)
# FC Libourne-Saint-Seurin.png   -> (300, 300)
# FC Lorient.png                 -> (300, 428)
# FC Martigues.png               -> (330, 429)
# FC Metz.png                    -> (225, 322)
# FC Mulhouse.png                -> (255, 255)
# FC Nantes.png                  -> (330, 425)
# FC Rouen 1899.png              -> (270, 319)
# FC Sochaux.png                 -> (300, 399)
# FC Sète.png                    -> (300, 353)
# FC Versailles.png              -> (320, 320)
# FC Villefranche Beaujolais.png -> (320, 346)
# Gap FC.png                     -> (300, 300)
# Gazélec FC Ajaccio.png         -> (270, 298)
# Girondins Bordeaux.png         -> (270, 331)
# GOAL FC.png                    -> (330, 327)
# Grenoble Foot 38.png           -> (330, 405)
# Havre AC.png                   -> (255, 311)
# Hyères FC.png                  -> (300, 427)
# JA Drancy.png                  -> (375, 501)
# La Roche-sur-Yon VF.png        -> (330, 330)
# LB Châteauroux.png             -> (285, 285)
# Le Mans FC.png                 -> (300, 300)
# Le Poiré-sur-Vie VF.png        -> (330, 405)
# Le Puy Foot 43.png             -> (320, 356)
# Lille OSC.png                  -> (323, 308)
# Louhans-Cuiseaux.png           -> (375, 413)
# Luzenac Ariège Pyrénées.png    -> (330, 330)
# Luçon VF.png                   -> (139, 181)
# Marignane Gignac.png           -> (330, 366)
# Marseille Consolat.png         -> (270, 287)
# Montpellier HSC.png            -> (300, 300)
# Nîmes Olympique.png            -> (270, 315)
# OGC Nice.png                   -> (255, 315)
# Olympique Alès-en-Cévennes.png -> (330, 376)
# Olympique Lyonnais.png         -> (270, 315)
# Olympique Marseille.png        -> (300, 389)
# Olympique Noisy-le-Sec Banlieue 93.png -> (375, 375)
# Pacy Vallée.png                -> (375, 615)
# Paris 13 Atletico.png          -> (330, 330)
# Paris FC.png                   -> (263, 313)
# Paris Saint-Germain.png        -> (315, 316)
# Pau FC.png                     -> (300, 300)
# Racing Besançon.png            -> (320, 361)
# RC France 92.png               -> (225, 282)
# RC Lens.png                    -> (310, 418)
# RC Strasbourg.png              -> (300, 300)
# Red Star FC.png                -> (330, 330)
# Rodez AF.png                   -> (225, 281)
# Saint-Denis Saint-Leu FC.png   -> (164, 139)
# SAS Épinal.png                 -> (330, 421)
# SC Aubagne Air-Bel.png         -> (316, 316)
# SC Bastia.png                  -> (240, 304)
# SC Toulon.png                  -> (300, 484)
# SM Caen.png                    -> (330, 440)
# SO Cassis-Carnoux.png          -> (375, 375)
# SO Cholet.png                  -> (330, 355)
# SO Châtellerault.png           -> (375, 375)
# SO Romorantin.png              -> (330, 330)
# SR Colmar.png                  -> (330, 369)
# Stade Beaucairois.png          -> (375, 433)
# Stade Brestois 29.png          -> (255, 309)
# Stade Briochin.png             -> (375, 481)
# Stade de Reims.png             -> (250, 498)
# Stade Lavallois.png            -> (320, 398)
# Stade Plabennec.png            -> (375, 365)
# Stade Poitevin.png             -> (300, 300)
# Stade Rennais.png              -> (285, 315)
# Thouars Foot 79.png            -> (225, 324)
# Toulouse FC.png                -> (300, 300)
# Tours FC.png                   -> (270, 265)
# Trélissac FC.png               -> (375, 441)
# UJA Alfortville.png            -> (840, 859)
# US Avranches.png               -> (285, 349)
# US Boulogne.png                -> (375, 458)
# US Colomiers.png               -> (270, 323)
# US Concarneau.png              -> (270, 320)
# US Créteil-Lusitanos.png       -> (255, 263)
# US Lusitanos de Saint-Maur.png -> (375, 375)
# US Orléans.png                 -> (300, 376)
# US Quevilly-Rouen.png          -> (270, 335)
# US Raon l'Etape.png            -> (375, 463)
# US Roye.png                    -> (323, 309)
# USJA Carquefou.png             -> (375, 453)
# USL Dunkerque.png              -> (300, 383)
# Valenciennes FC.png            -> (345, 385)
# Vannes OC.png                  -> (285, 386)
# Vendée Les Herbiers.png        -> (330, 358)
# Villemomble Sports.png         -> (300, 380)
# Étoile FC.png                  -> (330, 330)
# Évian Thonon Gaillard.png      -> (330, 384)

# %%
import os
from PIL import Image

def resize_and_pad(img, size=(256, 256), color=(0, 0, 0, 0)):
    """
    Resize proportionnellement une image puis ajoute du padding
    pour obtenir exactement (size[0], size[1]).
    
    Args:
        img (PIL.Image): image d'entrée
        size (tuple): (largeur, hauteur) cible
        color (tuple): couleur de fond RGBA (par défaut transparent)
    """
    img.thumbnail(size, Image.LANCZOS)  # resize proportionnel
    new_img = Image.new("RGBA", size, color)  # carré vide
    offset = ((size[0] - img.size[0]) // 2, (size[1] - img.size[1]) // 2)
    new_img.paste(img, offset)
    return new_img

def process_logos(input_folder, output_folder, size=(128, 128)):
    os.makedirs(output_folder, exist_ok=True)

    for file in os.listdir(input_folder):
        if file.lower().endswith((".png", ".jpg", ".jpeg")):
            path_in = os.path.join(input_folder, file)
            path_out = os.path.join(output_folder, file)
            try:
                with Image.open(path_in) as img:
                    img = img.convert("RGBA")
                    final_img = resize_and_pad(img, size=size)
                    final_img.save(path_out)
                    print(f"✅ {file} traité -> {path_out}")
            except Exception as e:
                print(f"⚠️ Erreur avec {file}: {e}")

# Exemple d'utilisation
process_logos(
    input_folder="C:\\1_Programmes Python\\Statistiques\\Classement Elo foot\\New version\\Logos\\logos_original_size",
    output_folder="C:\\1_Programmes Python\\Statistiques\\Classement Elo foot\\New version\\Logos\\Logos_resized",
    size=(256, 256)
)
# Out:
# ✅ AC Ajaccio.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AC Ajaccio.png
# ✅ AC Arles-Avignon.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AC Arles-Avignon.png
# ✅ AJ Auxerre.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AJ Auxerre.png
# ✅ Amiens SC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Amiens SC.png
# ✅ Angers SCO.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Angers SCO.png
# ✅ AS Angoulême Charente.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Angoulême Charente.png
# ✅ AS Beauvais.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Beauvais.png
# ✅ AS Béziers.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Béziers.png
# ✅ AS Cannes.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Cannes.png
# ✅ AS Cherbourg.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Cherbourg.png
# ✅ AS Lyon Duchère.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Lyon Duchère.png
# ✅ AS Monaco.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Monaco.png
# ✅ AS Moulins.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Moulins.png
# ✅ AS Nancy Lorraine.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Nancy Lorraine.png
# ✅ AS Saint-Priest.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Saint-Priest.png
# ✅ AS Saint-Étienne.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Saint-Étienne.png
# ✅ AS Yzeure FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Yzeure FC.png
# ✅ AS Évry.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\AS Évry.png
# ✅ ASM Belfort.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\ASM Belfort.png
# ✅ ASOA Valence.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\ASOA Valence.png
# ✅ Aviron Bayonnais.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Aviron Bayonnais.png
# ✅ CA Bastia.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\CA Bastia.png
# ✅ Calais RUFC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Calais RUFC.png
# ✅ Chamois Niortais.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Chamois Niortais.png
# ✅ Clermont Foot 63.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Clermont Foot 63.png
# ✅ CS Sedan.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\CS Sedan.png
# ✅ Dijon FCO.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Dijon FCO.png
# ✅ EA Guingamp.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\EA Guingamp.png
# ✅ Entente SSG.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Entente SSG.png
# ✅ ES Uzès Pont du Gard.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\ES Uzès Pont du Gard.png
# ✅ ES Viry-Châtillon.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\ES Viry-Châtillon.png
# ✅ ES Wasquehal.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\ES Wasquehal.png
# ✅ ESTAC Troyes.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\ESTAC Troyes.png
# ✅ FC Annecy.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Annecy.png
# ✅ FC Borgo.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Borgo.png
# ✅ FC Bourg-Péronnas.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Bourg-Péronnas.png
# ✅ FC Chambly.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Chambly.png
# ✅ FC Fleury 91.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Fleury 91.png
# ✅ FC Gueugnon.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Gueugnon.png
# ✅ FC Istres.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Istres.png
# ✅ FC Libourne-Saint-Seurin.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Libourne-Saint-Seurin.png
# ✅ FC Lorient.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Lorient.png
# ✅ FC Martigues.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Martigues.png
# ✅ FC Metz.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Metz.png
# ✅ FC Mulhouse.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Mulhouse.png
# ✅ FC Nantes.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Nantes.png
# ✅ FC Rouen 1899.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Rouen 1899.png
# ✅ FC Sochaux.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Sochaux.png
# ✅ FC Sète.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Sète.png
# ✅ FC Versailles.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Versailles.png
# ✅ FC Villefranche Beaujolais.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\FC Villefranche Beaujolais.png
# ✅ Gap FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Gap FC.png
# ✅ Gazélec FC Ajaccio.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Gazélec FC Ajaccio.png
# ✅ Girondins Bordeaux.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Girondins Bordeaux.png
# ✅ GOAL FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\GOAL FC.png
# ✅ Grenoble Foot 38.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Grenoble Foot 38.png
# ✅ Havre AC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Havre AC.png
# ✅ Hyères FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Hyères FC.png
# ✅ JA Drancy.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\JA Drancy.png
# ✅ La Roche-sur-Yon VF.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\La Roche-sur-Yon VF.png
# ✅ LB Châteauroux.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\LB Châteauroux.png
# ✅ Le Mans FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Le Mans FC.png
# ✅ Le Poiré-sur-Vie VF.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Le Poiré-sur-Vie VF.png
# ✅ Le Puy Foot 43.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Le Puy Foot 43.png
# ✅ Lille OSC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Lille OSC.png
# ✅ Louhans-Cuiseaux.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Louhans-Cuiseaux.png
# ✅ Luzenac Ariège Pyrénées.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Luzenac Ariège Pyrénées.png
# ✅ Luçon VF.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Luçon VF.png
# ✅ Marignane Gignac.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Marignane Gignac.png
# ✅ Marseille Consolat.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Marseille Consolat.png
# ✅ Montpellier HSC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Montpellier HSC.png
# ✅ Nîmes Olympique.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Nîmes Olympique.png
# ✅ OGC Nice.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\OGC Nice.png
# ✅ Olympique Alès-en-Cévennes.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Olympique Alès-en-Cévennes.png
# ✅ Olympique Lyonnais.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Olympique Lyonnais.png
# ✅ Olympique Marseille.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Olympique Marseille.png
# ✅ Olympique Noisy-le-Sec Banlieue 93.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Olympique Noisy-le-Sec Banlieue 93.png
# ✅ Pacy Vallée.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Pacy Vallée.png
# ✅ Paris 13 Atletico.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Paris 13 Atletico.png
# ✅ Paris FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Paris FC.png
# ✅ Paris Saint-Germain.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Paris Saint-Germain.png
# ✅ Pau FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Pau FC.png
# ✅ Racing Besançon.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Racing Besançon.png
# ✅ RC France 92.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\RC France 92.png
# ✅ RC Lens.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\RC Lens.png
# ✅ RC Strasbourg.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\RC Strasbourg.png
# ✅ Red Star FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Red Star FC.png
# ✅ Rodez AF.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Rodez AF.png
# ✅ Saint-Denis Saint-Leu FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Saint-Denis Saint-Leu FC.png
# ✅ SAS Épinal.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\SAS Épinal.png
# ✅ SC Aubagne Air-Bel.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\SC Aubagne Air-Bel.png
# ✅ SC Bastia.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\SC Bastia.png
# ✅ SC Toulon.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\SC Toulon.png
# ✅ SM Caen.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\SM Caen.png
# ✅ SO Cassis-Carnoux.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\SO Cassis-Carnoux.png
# ✅ SO Cholet.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\SO Cholet.png
# ✅ SO Châtellerault.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\SO Châtellerault.png
# ✅ SO Romorantin.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\SO Romorantin.png
# ✅ SR Colmar.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\SR Colmar.png
# ✅ Stade Beaucairois.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Stade Beaucairois.png
# ✅ Stade Brestois 29.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Stade Brestois 29.png
# ✅ Stade Briochin.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Stade Briochin.png
# ✅ Stade de Reims.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Stade de Reims.png
# ✅ Stade Lavallois.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Stade Lavallois.png
# ✅ Stade Plabennec.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Stade Plabennec.png
# ✅ Stade Poitevin.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Stade Poitevin.png
# ✅ Stade Rennais.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Stade Rennais.png
# ✅ Thouars Foot 79.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Thouars Foot 79.png
# ✅ Toulouse FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Toulouse FC.png
# ✅ Tours FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Tours FC.png
# ✅ Trélissac FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Trélissac FC.png
# ✅ UJA Alfortville.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\UJA Alfortville.png
# ✅ US Avranches.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\US Avranches.png
# ✅ US Boulogne.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\US Boulogne.png
# ✅ US Colomiers.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\US Colomiers.png
# ✅ US Concarneau.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\US Concarneau.png
# ✅ US Créteil-Lusitanos.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\US Créteil-Lusitanos.png
# ✅ US Lusitanos de Saint-Maur.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\US Lusitanos de Saint-Maur.png
# ✅ US Orléans.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\US Orléans.png
# ✅ US Quevilly-Rouen.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\US Quevilly-Rouen.png
# ✅ US Raon l'Etape.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\US Raon l'Etape.png
# ✅ US Roye.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\US Roye.png
# ✅ USJA Carquefou.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\USJA Carquefou.png
# ✅ USL Dunkerque.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\USL Dunkerque.png
# ✅ Valenciennes FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Valenciennes FC.png
# ✅ Vannes OC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Vannes OC.png
# ✅ Vendée Les Herbiers.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Vendée Les Herbiers.png
# ✅ Villemomble Sports.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Villemomble Sports.png
# ✅ Étoile FC.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Étoile FC.png
# ✅ Évian Thonon Gaillard.png traité -> C:\1_Programmes Python\Statistiques\Classement Elo foot\New version\Logos\Logos_resized\Évian Thonon Gaillard.png
